# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from datetime import datetime
warnings.filterwarnings(action='ignore')

train = pd.read_csv("C:/Users/jlee0/Desktop/공모전/공모전/train.csv", encoding='UTF8')
test = pd.read_csv("C:/Users/jlee0/Desktop/공모전/공모전/test.csv", encoding='UTF8')

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 메타 데이터
#
# identity
#
# - person_rn : 사용자 구분
#
# - contents_rn : 컨텐츠 구분
#
# - contents_open_dt : 컨텐츠를 이용한 일시
#
#
# target
#
# - target : 컨텐츠 사용 여부
#
#
# content attribute
#
# - contents_attribute_i,,,h : 컨텐츠 속성 i,,,h
#
#
# person attribute
#
# - person_attribute_a,,,h_3 : 회원 특성 a,,,h_3
#
#
# match
#
# - d(h)_l(m,s)_match_yn : 회원과 컨텐츠 속성 일치 여부

# %%
from typing import Dict
import numpy as np
import pandas as pd

# %%
def add_code(
    df: pd.DataFrame,
    d_code: Dict[int, Dict[str, int]], 
    h_code: Dict[int, Dict[str, int]], 
    l_code: Dict[int, Dict[str, int]],
) -> pd.DataFrame:
    
    # Copy input data
    df = df.copy()   

    # D Code
    df['person_prefer_d_1_n'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_1_s'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_1_m'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_1_l'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_2_n'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_2_s'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_2_m'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_2_l'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_3_n'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_3_s'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_3_m'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_3_l'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['contents_attribute_d_n'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['contents_attribute_d_s'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['contents_attribute_d_m'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['contents_attribute_d_l'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    # H Code
    df['person_prefer_h_1_l'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_1_m'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    
    df['person_prefer_h_2_l'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_2_m'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    
    df['person_prefer_h_3_l'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_3_m'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

    df['contents_attribute_h_l'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['contents_attribute_h_m'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

    # L Code
    df['contents_attribute_l_n'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 세분류코드'])
    df['contents_attribute_l_s'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 소분류코드'])
    df['contents_attribute_l_m'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 중분류코드'])
    df['contents_attribute_l_l'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 대분류코드'])
    
    return df

pd.read_csv("C:/Users/jlee0/Desktop/공모전/공모전/속성_D_코드.csv", index_col=0,encoding='UTF8')
pd.read_csv("C:/Users/jlee0/Desktop/공모전/공모전/속성_H_코드.csv", index_col=0, encoding='UTF8')
pd.read_csv("C:/Users/jlee0/Desktop/공모전/공모전/속성_L_코드.csv", index_col=0, encoding='UTF8')

d_code = pd.read_csv('/content/drive/MyDrive/Jobcare_data/속성_D_코드.csv', index_col=0).T.to_dict()
h_code = pd.read_csv('/content/drive/MyDrive/Jobcare_data/속성_H_코드.csv', index_col=0).T.to_dict()
l_code = pd.read_csv('/content/drive/MyDrive/Jobcare_data/속성_L_코드.csv', index_col=0).T.to_dict()

train_data = pd.read_csv('/content/drive/MyDrive/Jobcare_data/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Jobcare_data/test.csv')

train_data = add_code(train_data, d_code, h_code, l_code)
test_data = add_code(test_data, d_code, h_code, l_code)

# %%
print("train_data.shape: ", train_data.shape)
print("test_data.shape: ", test_data.shape)
# Out:
# train_data.shape:  (501951, 63)
# test_data.shape:  (46404, 62)

# %%
train_data
# Out:
#             id  d_l_match_yn  ...  contents_attribute_l_m  contents_attribute_l_l
# 0            0          True  ...                    1605                    2016
# 1            1         False  ...                    1605                    2016
# 2            2         False  ...                    1572                    2016
# 3            3         False  ...                    1605                    2016
# 4            4          True  ...                    1605                    2016
# ...        ...           ...  ...                     ...                     ...
# 501946  501946         False  ...                     346                    2006
# 501947  501947          True  ...                      99                    2006
# 501948  501948          True  ...                     407                    2006
# 501949  501949          True  ...                     651                    2006
# ...

# %%
def preprocessing_contents_open_dt(data):
    data['contents_open_dt'] = data['contents_open_dt'].astype('str')
    DATE = data['contents_open_dt'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
    
    DATE = pd.DataFrame(DATE)
    DATE = DATE.rename(columns = {'contents_open_dt': 'date'})
    
    DATE['Y'] = DATE['date'].apply(lambda x: x.timetuple()[0])
    DATE['M'] = DATE['date'].apply(lambda x: x.timetuple()[1])
    DATE['D'] = DATE['date'].apply(lambda x: x.timetuple()[2])
    DATE['id'] = data['id']
    
    data = data.merge(DATE, on = 'id', how = 'left')
    data = data.drop(columns = ['date', 'contents_open_dt'])
    return data

train_data = preprocessing_contents_open_dt(train_data)
test_data = preprocessing_contents_open_dt(test_data)

# 안전하게 확인하고 넘어 갑시다. 
train_data_labels = train_data['target']
train_data, test_data = train_data.align(test_data, join = 'inner', axis = 1)
train_data['target'] = train_data_labels
print("train_data.shape: ", train_data.shape)
print("test_data.shape: ", test_data.shape)
# Out:
# train_data.shape:  (501951, 65)
# test_data.shape:  (46404, 64)

# %%
job_data = train_data.copy()
job_data_test = test_data.copy()

# %% [markdown]
# # Naive modeling

# %%
#job_data의 bool형 값들을 1,0으로 대체한다.

for column in job_data.select_dtypes(include='bool').columns:
    job_data[column] = job_data[column].astype(int)
    
for column in job_data_test.select_dtypes(include='bool').columns:
    job_data_test[column] = job_data_test[column].astype(int)

# %%
job_data.dtypes
# Out:
# id                        int64
# d_l_match_yn              int64
# d_m_match_yn              int64
# d_s_match_yn              int64
# h_l_match_yn              int64
#                           ...
# contents_attribute_l_l    int64
# Y                         int64
# M                         int64
# D                         int64
# target                    int64
# Length: 65, dtype: object

# %%
categorical_only_train=job_data.drop(['id', 'd_l_match_yn', 'd_m_match_yn', 'd_s_match_yn', 'h_l_match_yn',
       'h_m_match_yn', 'h_s_match_yn','person_attribute_a_1', 'person_attribute_b','person_prefer_e','contents_attribute_e','person_rn', 'contents_rn','Y', 'M', 'D',
       'target'], axis=1)

# %% [markdown]
# CatBoost Encoder는 str의 columns에 대해서 인코딩이 진행되므로 int형의 명목형 변수 column들을 str로 변환

# %%
categorical_only_train=categorical_only_train.applymap(str)

# %%
categorical_only_train.dtypes
# Out:
# person_attribute_a        object
# person_prefer_c           object
# person_prefer_d_1         object
# person_prefer_d_2         object
# person_prefer_d_3         object
# person_prefer_f           object
# person_prefer_g           object
# person_prefer_h_1         object
# person_prefer_h_2         object
# person_prefer_h_3         object
# contents_attribute_i      object
# contents_attribute_a      object
# contents_attribute_j_1    object
# contents_attribute_j      object
# contents_attribute_c      object
# contents_attribute_k      object
# contents_attribute_l      object
# contents_attribute_d      object
# contents_attribute_m      object
# contents_attribute_h      object
# person_prefer_d_1_n       object
# person_prefer_d_1_s       object
# person_prefer_d_1_m       object
# person_prefer_d_1_l       object
# person_prefer_d_2_n       object
# person_prefer_d_2_s       object
# person_prefer_d_2_m       object
# person_prefer_d_2_l       object
# ...

# %% [markdown]
# categorical_only_test, categorical_only_test ==> 명목형 변수들만 있는 df
#
# not_categorical_train,categorical_only_test ==> 순서형 변수들만 있는 df

# %%
categorical_only_test=job_data_test.drop(['id', 'd_l_match_yn', 'd_m_match_yn', 'd_s_match_yn', 'h_l_match_yn',
       'h_m_match_yn', 'h_s_match_yn','person_attribute_a_1', 'person_attribute_b','person_prefer_e','contents_attribute_e','person_rn', 'contents_rn','Y', 'M', 'D'], axis=1)

# %%
categorical_only_test=categorical_only_test.applymap(str)

# %%
categorical_only_test.columns
# Out:
# Index(['person_attribute_a', 'person_prefer_c', 'person_prefer_d_1',
#        'person_prefer_d_2', 'person_prefer_d_3', 'person_prefer_f',
#        'person_prefer_g', 'person_prefer_h_1', 'person_prefer_h_2',
#        'person_prefer_h_3', 'contents_attribute_i', 'contents_attribute_a',
#        'contents_attribute_j_1', 'contents_attribute_j',
#        'contents_attribute_c', 'contents_attribute_k', 'contents_attribute_l',
#        'contents_attribute_d', 'contents_attribute_m', 'contents_attribute_h',
#        'person_prefer_d_1_n', 'person_prefer_d_1_s', 'person_prefer_d_1_m',
#        'person_prefer_d_1_l', 'person_prefer_d_2_n', 'person_prefer_d_2_s',
#        'person_prefer_d_2_m', 'person_prefer_d_2_l', 'person_prefer_d_3_n',
#        'person_prefer_d_3_s', 'person_prefer_d_3_m', 'person_prefer_d_3_l',
#        'contents_attribute_d_n', 'contents_attribute_d_s',
#        'contents_attribute_d_m', 'contents_attribute_d_l',
# ...

# %%
target=job_data.loc[:,'target']

# %%
not_categorical_train=job_data.loc[:,['id', 'd_l_match_yn', 'd_m_match_yn', 'd_s_match_yn', 'h_l_match_yn',
       'h_m_match_yn', 'h_s_match_yn','person_attribute_a_1', 'person_attribute_b','person_prefer_e','contents_attribute_e','person_rn', 'contents_rn','Y', 'M', 'D',
       'target']]

# %%
not_categorical_test=job_data_test.loc[:,['id', 'd_l_match_yn', 'd_m_match_yn', 'd_s_match_yn', 'h_l_match_yn',
       'h_m_match_yn', 'h_s_match_yn','person_attribute_a_1', 'person_attribute_b','person_prefer_e','contents_attribute_e','person_rn', 'contents_rn','Y', 'M', 'D']]

# %%
pip install --upgrade category_encoders
# Out:
# ...
#      |████████████████████████████████| 82 kB 386 kB/s
# ...

# %% [markdown]
# X_train: 명목형, 순서형 변수 모두 합친 x_feature(target 제외)

# %%
X_train = pd.concat([categorical_only_train,not_categorical_train],axis=1)

# %%
X_train.drop(['target'],inplace=True, axis=1)

# %%
X_test=pd.concat([categorical_only_test,not_categorical_test],axis=1)

# %%
import category_encoders as ce
# cols에 기재된 column에 대해서만 encoding 진행됨
CBE_encoder = ce.cat_boost.CatBoostEncoder(cols=['person_attribute_a', 'person_prefer_c', 'person_prefer_d_1',
       'person_prefer_d_2', 'person_prefer_d_3', 'person_prefer_f',
       'person_prefer_g', 'person_prefer_h_1', 'person_prefer_h_2',
       'person_prefer_h_3', 'contents_attribute_i', 'contents_attribute_a',
       'contents_attribute_j_1', 'contents_attribute_j',
       'contents_attribute_c', 'contents_attribute_k', 'contents_attribute_l',
       'contents_attribute_d', 'contents_attribute_m', 'contents_attribute_h',
       'person_prefer_d_1_n', 'person_prefer_d_1_s', 'person_prefer_d_1_m',
       'person_prefer_d_1_l', 'person_prefer_d_2_n', 'person_prefer_d_2_s',
       'person_prefer_d_2_m', 'person_prefer_d_2_l', 'person_prefer_d_3_n',
       'person_prefer_d_3_s', 'person_prefer_d_3_m', 'person_prefer_d_3_l',
       'contents_attribute_d_n', 'contents_attribute_d_s',
       'contents_attribute_d_m', 'contents_attribute_d_l',
       'person_prefer_h_1_l', 'person_prefer_h_1_m', 'person_prefer_h_2_l',
       'person_prefer_h_2_m', 'person_prefer_h_3_l', 'person_prefer_h_3_m',
       'contents_attribute_h_l', 'contents_attribute_h_m',
       'contents_attribute_l_n', 'contents_attribute_l_s',
       'contents_attribute_l_m', 'contents_attribute_l_l'])
CBE_encoder.fit(X_train, target)
train_cbe = CBE_encoder.transform(X_train)
test_cbe = CBE_encoder.transform(X_test)

# %% [markdown]
# test_cbe는 target value 없어서 train data로 split

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(train_cbe, target, test_size=.3)

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier()
rf.fit(x_train, y_train)
rf.score(x_test,y_test)
# Out:
# 0.7308647550237074
